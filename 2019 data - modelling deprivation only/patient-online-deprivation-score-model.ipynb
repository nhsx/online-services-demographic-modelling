# %% [markdown]
# # patient-online-deprivation-score-model-2019-data
# #### Developed by: Mary Amanuel
# #### Contact: mary.amanuel@nhsx.nhs.uk
# #### Created: 22nd November 2021
# #### Last updated: 4th January 2021

# %%
import pandas as pd
import os
import plotly
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import json
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# ### 'Public Health England. Public Health Profiles. [22/11/2021] https://fingertips.phe.org.uk © Crown copyright [2021]'
# ##### The English Indices of Deprivation 2019 - Technical documentation for data here: https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/833951/IoD2019_Technical_Report.pdf
#
# ##### The English Indices of Deprivation 2019 - Research documentation for data here: https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/833947/IoD2019_Research_Report.pdf

# %%
# Import fingertips_py package - This is a python package to interact with Public Health England’s [Fingertips](https://fingertips.phe.org.uk/) data tool. Fingertips is a major repository of population and public health indicators for England.
## https://fingertips-py.readthedocs.io/en/latest/#indices-and-table
## Installing the fingertips_py library (if not already)

# !pip install fingertips_py
import fingertips_py
# Out:
# Requirement already satisfied: fingertips_py in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (0.2.2)
# Requirement already satisfied: pandas>=0.18.1 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from fingertips_py) (1.2.4)
# Requirement already satisfied: requests in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from fingertips_py) (2.25.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18.1->fingertips_py) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18.1->fingertips_py) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.18.1->fingertips_py) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.18.1->fingertips_py) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from requests->fingertips_py) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from requests->fingertips_py) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from requests->fingertips_py) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mary.amanuel/opt/anaconda3/lib/python3.8/site-packages (from requests->fingertips_py) (2020.12.5)

# %%
national_gp_profiles = fingertips_py.get_profile_by_name('National General Practice Profiles')
national_gp_profiles
# Out:
# {'Id': 21,
#  'Name': 'National General Practice Profiles (supporting indicators)',
#  'Key': 'practice-profiles-supporting-indicators',
#  'GroupIds': [1200006],
#  'GroupMetadata': [{'Id': 1200006,
#    'Name': 'National GP Profiles - Supporting Indicators',
#    'Sequence': 1,
#    'ProfileId': 21,
#    'DataAvailable': [{'AreaTypeId': 7, 'IndicatorCount': 20},
#     {'AreaTypeId': 165, 'IndicatorCount': 20},
#     {'AreaTypeId': 166, 'IndicatorCount': 20},
#     {'AreaTypeId': 167, 'IndicatorCount': 20},
#     {'AreaTypeId': 204, 'IndicatorCount': 20},
#     {'AreaTypeId': 219, 'IndicatorCount': 20}]}],
#  'Visualisations': ['Overview',
#   'CompareAreas',
#   'Trends',
#   'AreaProfile',
#   'Definitions',
#   'Download'],
#  'HasRecentTrends': False,
#  'StartValueAxisFromZero': False,
#  'IsChangeFromPreviousPeriodShown': False,
#  'DefaultAreaTypeId': 7,
#  'DefaultTabId': 0,
#  'IgnoredSpineChartAreas': ['E06000053', 'E09000001'],
#  'OpenInequalitiesOnAreaData': False}

# %%
## Check the relevant geographies that can be called upon as area id. For instance, it can be seen that 'General Practice' is 7
fingertips_py.metadata.get_area_types_as_dict()
# Out:
# [{'Id': 3,
#   'Name': 'Middle Super Output Area',
#   'Short': 'MSOA',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 4,
#   'Name': 'Lower Super Output Area',
#   'Short': 'LSOA',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 6,
#   'Name': 'Government Office Region',
#   'Short': 'Region',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 7,
#   'Name': 'General Practice',
#   'Short': 'GP',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 8,
#   'Name': 'Ward',
#   'Short': 'Ward',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 14,
#   'Name': 'Acute Trust',
#   'Short': 'Acute Trust',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 15,
#   'Name': 'England',
#   'Short': 'England',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 20,
#   'Name': 'Mental Health Trust',
#   'Short': 'Mental Health Trust',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 41,
#   'Name': 'Ambulance Trust',
#   'Short': 'Ambulance Trust',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 42,
#   'Name': '2013 PHE Regions (4)',
#   'Short': 'PHE Region ',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 44,
#   'Name': 'E40, former commissioning regions',
#   'Short': 'NHS region',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 46,
#   'Name': 'E39, former sub-region, former Local area teams)',
#   'Short': 'NHS region - local office',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 48,
#   'Name': 'PHE Centres, not continued from 2015 onwards (11)',
#   'Short': 'PHE Centre 2013-2015',
#   'Class': 'phe-centre',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 49,
#   'Name': 'PHE Centres, new 2015 (5)',
#   'Short': 'PHE Centre from 2015',
#   'Class': 'phe-centre',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 50,
#   'Name': 'PHE Centres 2013, unchanged (4)',
#   'Short': 'PHE Centre from 2013',
#   'Class': 'phe-centre',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 54,
#   'Name': 'for years: 18/19, 19/20, 20/21, 21/22, ....? CCG introduced April 2018',
#   'Short': 'CCG new 2018',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 55,
#   'Name': 'for years: 17/18  CCG superseded April 2018',
#   'Short': 'CCGs old 2018',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 56,
#   'Name': 'for all years - unchanged since beginning. CCG still unchanged April 2021',
#   'Short': 'CCGs unchanged 2021',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 58,
#   'Name': 'for years: 19/20, 20/21, 21/22, .....? CCGs introduced April 2019',
#   'Short': 'CCGs new 2019',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 59,
#   'Name': 'for years: 17/18, 18/19. CCGs sup',
#   'Short': 'CCGs old 2019',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 60,
#   'Name': 'for years: 20/21, 21/22,....? CCGs introduced April 2020',
#   'Short': 'CCGs new 2020',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 62,
#   'Name': 'for years: 17/18, 18/19, 19/20. CCGs superseded 4/20 (split off from 56)',
#   'Short': 'CCGs old 2020',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 63,
#   'Name': 'for years: 21/22, ...? CCGs introduced April 2021',
#   'Short': 'CCGs new 2021',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 64,
#   'Name': 'for years: for years: 17/18, 18/19, 19/20, 20/21. CCGs old 2021',
#   'Short': 'CCGs old 2021',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 65,
#   'Name': 'for years: 18/19, 19/20, 20/21. CCG split off from 54',
#   'Short': 'CCGs new 2018 old 2021',
#   'Class': 'ccg',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 101,
#   'Name': 'Lower tier local authorities (pre 4/19)',
#   'Short': 'Districts & UAs (pre Apr 2019)',
#   'Class': 'ua-la-composite',
#   'Sequence': 2018,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 102,
#   'Name': 'Upper tier local authorities (pre 4/19)',
#   'Short': 'Counties & UAs (pre Apr 2019)',
#   'Class': 'ua-county-composite',
#   'Sequence': 2018,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 103,
#   'Name': 'PHEC 2013 only plus PHEC unchanged',
#   'Short': 'PHE Centres (2013)',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 104,
#   'Name': 'PHEC 2015 new plus PHEC 2013 unchanged',
#   'Short': 'PHE Centres (2015)',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 109,
#   'Name': 'ONS statistical neighbour cluster - top level',
#   'Short': 'ONS 2001 cluster supergroup',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 110,
#   'Name': 'ONS statistical neighbour cluster - middle level',
#   'Short': 'ONS 2001 cluster group',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 111,
#   'Name': 'ONS statistical neighbour cluster - bottom level',
#   'Short': 'ONS 2001 cluster subgroup',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 112,
#   'Name': 'Strategic Clinical Network',
#   'Short': 'Strategic Clinical Network',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 115,
#   'Name': 'ONS statistical neighbour cluster 2011 - middle level',
#   'Short': 'ONS 2011 group (superseded)',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 116,
#   'Name': 'ONS statistical neighbour cluster 2011 - bottom level',
#   'Short': 'ONS 2011 subgroup (superseded)',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 117,
#   'Name': 'Mental Health and Acute Trust combined',
#   'Short': 'MH and Acute Trust',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 118,
#   'Name': 'Acute Trusts (incl.combined MH+Acute)',
#   'Short': 'Acute Trusts',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 119,
#   'Name': 'Mental Health Trusts (incl.combined MH+Acute)',
#   'Short': 'Mental Health Trust',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 120,
#   'Name': 'Sustainability and Transformation Footprints',
#   'Short': 'STP (unchanged)',
#   'Class': 'stp',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 121,
#   'Name': 'Abdominal aortic aneurysm screening cohort',
#   'Short': 'AAA Screening Cohort',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 122,
#   'Name': 'Bowel Cancer Screening Centres',
#   'Short': 'Bowel Cancer Screening Centres',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 124,
#   'Name': 'Newborn Screening Sites',
#   'Short': 'Newborn Screening Sites',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 125,
#   'Name': 'Maternity Services',
#   'Short': 'Maternity Services',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 126,
#   'Name': 'Combined authorities',
#   'Short': 'Combined authorities',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 129,
#   'Name': 'Laboratory',
#   'Short': 'Laboratory',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 130,
#   'Name': 'Breast Screening Service',
#   'Short': 'Breast Screening Service',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 152,
#   'Name': 'CCGs (2017/18)',
#   'Short': 'CCGs (2017/18)',
#   'Class': 'ccg-composite',
#   'Sequence': 2017,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 154,
#   'Name': 'CCGs (2018/19)',
#   'Short': 'CCGs (2018/19)',
#   'Class': 'ccg-composite',
#   'Sequence': 2018,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 156,
#   'Name': 'ONS 2011 group (revised)',
#   'Short': 'ONS 2011 group',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 157,
#   'Name': 'ONS 2011 subgroup (revised)',
#   'Short': 'ONS 2011 subgroup',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 158,
#   'Name': 'Hospital trust type',
#   'Short': 'Trust type',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 159,
#   'Name': 'United Kingdom',
#   'Short': 'UK',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 160,
#   'Name': 'LA unchanged',
#   'Short': 'LA unchanged',
#   'Class': 'la',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 161,
#   'Name': 'LA new 2019',
#   'Short': 'LA new 2019',
#   'Class': 'la',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 162,
#   'Name': 'LA old 2019',
#   'Short': 'LA obsolete 2019',
#   'Class': 'la',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 163,
#   'Name': 'LA old 2020',
#   'Short': 'LA obsolete 2020',
#   'Class': 'la',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 164,
#   'Name': 'LA old 2021',
#   'Short': 'LA obsolete 2021',
#   'Class': 'la',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 165,
#   'Name': 'CCGs (2019/20)',
#   'Short': 'CCGs (2019/20)',
#   'Class': 'ccg-composite',
#   'Sequence': 2019,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 166,
#   'Name': 'CCGs (2020/21)',
#   'Short': 'CCGs (2020/21)',
#   'Class': 'ccg-composite',
#   'Sequence': 2020,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 167,
#   'Name': 'CCGs (2021/22)',
#   'Short': 'CCGs (from Apr 2021)',
#   'Class': 'ccg-composite',
#   'Sequence': 2021,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 170,
#   'Name': 'UA unchanged',
#   'Short': 'UA unchanged',
#   'Class': 'ua',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 171,
#   'Name': 'UA new 2019',
#   'Short': 'UA new 2019',
#   'Class': 'ua',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 172,
#   'Name': 'UA old 2019',
#   'Short': 'UA obsolete 2019',
#   'Class': 'ua',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 173,
#   'Name': 'UA new 2020',
#   'Short': 'UA new 2020',
#   'Class': 'ua',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 174,
#   'Name': 'UA new 2021',
#   'Short': 'UA new 2021',
#   'Class': 'ua',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 180,
#   'Name': 'County unchanged',
#   'Short': 'County unchanged',
#   'Class': 'county',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 182,
#   'Name': 'County old 2019',
#   'Short': 'County obsolete 2019',
#   'Class': 'county',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 183,
#   'Name': 'County old 2020',
#   'Short': 'County obsolete 2020',
#   'Class': 'county',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 184,
#   'Name': 'County old 2021',
#   'Short': 'County obsolete 2021',
#   'Class': 'county',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 201,
#   'Name': 'Lower tier local authorities (4/19 - 3/20)',
#   'Short': 'Districts & UAs (2019/20)',
#   'Class': 'ua-la-composite',
#   'Sequence': 2019,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 202,
#   'Name': 'Upper tier local authorities (4/19 - 3/20)',
#   'Short': 'Counties & UAs (2019/20)',
#   'Class': 'ua-county-composite',
#   'Sequence': 2019,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 203,
#   'Name': 'IAPT services',
#   'Short': 'IAPT services',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 204,
#   'Name': 'Primary Care Network (v. 29/10/20)',
#   'Short': 'PCN (v. 28/10/21)',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 205,
#   'Name': 'Local Maternity System',
#   'Short': 'Local Maternity System',
#   'Class': None,
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 217,
#   'Name': 'STP',
#   'Short': 'STP (new 4/20)',
#   'Class': 'stp',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 218,
#   'Name': 'STP',
#   'Short': 'STP (obsolete)',
#   'Class': 'stp',
#   'Sequence': 0,
#   'CanBeDisplayedOnMap': False},
#  {'Id': 219,
#   'Name': 'STP (120 +218)',
#   'Short': 'STPs (pre Apr 2020)',
#   'Class': 'stp-composite',
#   'Sequence': 2019,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 220,
#   'Name': 'Sustainability and Transformation Footprints',
#   'Short': 'STPs (from Apr 2020)',
#   'Class': 'stp-composite',
#   'Sequence': 2020,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 301,
#   'Name': 'Lower tier local authorities (4/20-3/21)',
#   'Short': 'Districts & UAs (2020/21)',
#   'Class': 'ua-la-composite',
#   'Sequence': 2020,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 302,
#   'Name': 'Upper tier local authorities (4/20-3/21)',
#   'Short': 'Counties & UAs (2020/21)',
#   'Class': 'ua-county-composite',
#   'Sequence': 2020,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 401,
#   'Name': 'Lower tier local authorities (post 4/21)',
#   'Short': 'Districts & UAs (from Apr 2021)',
#   'Class': 'ua-la-composite',
#   'Sequence': 2021,
#   'CanBeDisplayedOnMap': True},
#  {'Id': 402,
#   'Name': 'Upper tier local authorities (post 4/21)',
#   'Short': 'Counties & UAs (from Apr 2021)',
#   'Class': 'ua-county-composite',
#   'Sequence': 2021,
#   'CanBeDisplayedOnMap': True}]

# %%
# Obtain dataframe with metadata on metrics under chosen topic (can instead just navigate website direct)
national_gp_profiles_meta = fingertips_py.get_metadata_for_profile_as_dataframe(national_gp_profiles['Id'])
national_gp_profiles_meta
# Out:
#    Indicator ID                                          Indicator  \
# 0           337  GP registered population by sex and quinary ag...
# 1           114                                QOF Total List Size
# 2           295                                   Total QOF points
# 3           650                       Life expectancy - MSOA based
# 4         93438  % who have a positive experience of their GP p...
# 5          1679                                Ethnicity estimates
# 6         93558  IDACI - Income Deprivation Affecting Children ...
# 7         93559  IDAOPI - Income Deprivation Affecting Older Pe...
# 8         93553                       Deprivation score (IMD 2019)
#
#                                           Definition  \
# 0  Number of males and females registered with a ...
# 1  Total number of patients registered with the p...
# 2  The percentage of all QOF points achieved acro...
# 3  Life expectancy at birth. Population weighting...
# 4  Question 30. People were asked: "Overall, how ...
# 5  Estimated proportion of non-white ethnic group...
# 6  This is a subset of the Income Deprivation Dom...
# 7  This is a subset of the Income Deprivation Dom...
# 8  The English Indices of Deprivation 2019 use 39...
#
#                                            Rationale  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Life expectancy at birth is chosen as the pref...
# 4                                                NaN
# 5                                                NaN
# 6  The Income Deprivation Affecting Children Inde...
# 7  Deprivation is one of the strongest predictors...
# 8  Deprivation covers a broad range of issues and...
#
#                                          Data source  \
# 0                                        NHS digital
# 1  Quality and Outcomes Framework (QOF), NHS Digital
# 2  Quality and Outcomes Framework (QOF), NHS Digital
# 3                   PHE, based on ONS mortality data
# 4                                  GP Patient Survey
# 5  Census 2011(Ethnicity by LSOA); HSCIC: Numbers...
# 6  Ministry of Housing, Communities & Local Gover...
# 7  Ministry of Housing, Communities & Local Gover...
# 8  Ministry of Housing, Communities & Local Gover...
#
#                                     Indicator source  \
# 0  Data for April of the respective calendar year...
# 1  Data for 2020/21 can be downloaded from  https...
# 2  Data for 2020/21 can be downloaded from https:...
# 3  http://www.localhealth.org.uk for MSOA life ex...
# 4                        http://www.gp-patient.co.uk
# 5  Department of Primary Care and Public Health S...
# 6  IDAOPI and IDACI are part of the English Indic...
# 7  The IDACI and IDAOPI are part of the English I...
# 8  https://www.gov.uk/government/statistics/engli...
#
#                                          Methodology  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The life expectancy for the MSOAs where the pr...
# 4                                                NaN
# 5                                                NaN
# 6  Where area values have been published in the d...
# 7  Where area values have been published in the d...
# 8  The English Indices of Deprivation 2019 are me...
#
#    Standard population/values  Confidence interval details  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# 5                         NaN                          NaN
# 6                         NaN                          NaN
# 7                         NaN                          NaN
# 8                         NaN                          NaN
#
#                                  Source of numerator  ...  \
# 0                                                NaN  ...
# 1  Quality and Outcomes Framework (QOF), NHS Digital  ...
# 2  Quality and Outcomes Framework (QOF), NHS Digital  ...
# 3                                                NaN  ...
# 4                                                NaN  ...
# 5                                                NaN  ...
# 6                                                NaN  ...
# 7                                                NaN  ...
# 8                                                NaN  ...
#
#                                                Notes  \
# 0  Data are extracted as monthly snapshot in time...
# 1                                                NaN
# 2  The maximal number of QOF points in 2013/14 wa...
# 3  This indicator was initially calculated for MS...
# 4  The number of this question has changed from 3...
# 5  If an ethnic group's proportion is smaller tha...
# 6                                                NaN
# 7                                                NaN
# 8  The Indices of Deprivation 2019 are relative m...
#
#                                            Frequency Rounding  \
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                                                NaN      NaN
# 5                                                NaN      NaN
# 6  The indices of deprivation are published in ir...      NaN
# 7  The indices of deprivation are published in ir...      NaN
# 8                                                NaN      NaN
#
#    Indicator Content Specific rationale  \
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# 5                NaN                NaN
# 6                NaN                NaN
# 7                NaN                NaN
# 8                NaN                NaN
#
#                                   Impact of COVID-19   Unit       Value type  \
# 0                                                NaN    NaN            Count
# 1                                                NaN    NaN            Count
# 2  NHS Digital have stated that changes in QOF du...      %       Proportion
# 3                                                NaN  Years  Life expectancy
# 4                                                NaN      %       Proportion
# 5                                                NaN      %       Proportion
# 6                                                NaN    NaN       Proportion
# 7                                                NaN    NaN       Proportion
# 8                                                NaN    NaN            Score
#
#    Year type                Polarity
# 0   Calendar    Not applicable
# 1  Financial    Not applicable
# 2  Financial    RAG - High is good
# 3   Calendar    RAG - High is good
# 4   Calendar  BOB - Blue orange blue
# 5  Financial    Not applicable
# 6   Calendar    RAG - Low is good
# 7   Calendar    RAG - Low is good
# 8   Calendar    RAG - Low is good
#
# [9 rows x 29 columns]

# %% [markdown]
# ### Focus: Deprivation Score vs Online Services
# #### 1) Data prep: Processing, cleaning and transformation

# %%
gp_and_england_deprivation_score = fingertips_py.retrieve_data.get_data_by_indicator_ids(indicator_ids=[93553],area_type_id =[7] ) # 7 for practice (we know this topic area has practice breakdown for sure, by design), 93553 for our metric of interest
gp_and_england_deprivation_score
# Out:
#       Indicator ID                Indicator Name Parent Code Parent Name  \
# 0            93553  Deprivation score (IMD 2019)         NaN         NaN
# 1            93553  Deprivation score (IMD 2019)   E92000001     England
# 2            93553  Deprivation score (IMD 2019)   E92000001     England
# 3            93553  Deprivation score (IMD 2019)   E92000001     England
# 4            93553  Deprivation score (IMD 2019)   E92000001     England
# ...            ...                           ...         ...         ...
# 7603         93553  Deprivation score (IMD 2019)   E92000001     England
# 7604         93553  Deprivation score (IMD 2019)   E92000001     England
# 7605         93553  Deprivation score (IMD 2019)   E92000001     England
# 7606         93553  Deprivation score (IMD 2019)   E92000001     England
# 7607         93553  Deprivation score (IMD 2019)   E92000001     England
#
#       Area Code                   Area Name Area Type      Sex       Age  \
# 0     E92000001                     England   England  Persons  All ages
# 1        A81001         The Densham Surgery        GP  Persons  All ages
# 2        A81002  Queens Park Medical Centre        GP  Persons  All ages
# 3        A81004     Bluebell Medical Centre        GP  Persons  All ages
# 4        A81005          Springwood Surgery        GP  Persons  All ages
# ...         ...                         ...       ...      ...       ...
# 7603     Y05857                        RHND        GP  Persons  All ages
# 7604     Y06007   Wellbourne Healthcare CIC        GP  Persons  All ages
# 7605     Y06113    QHS GP Care Home Service        GP  Persons  All ages
# 7606     Y06218   Brownsover Medical Centre        GP  Persons  All ages
# 7607     Y06275       Nelson Medical Centre        GP  Persons  All ages
#
#       Category Type  ...  Upper CI 99.8 limit  Count  Denominator  Value note  \
# 0               NaN  ...                  NaN    NaN          NaN         NaN
# 1               NaN  ...                  NaN    NaN          NaN         NaN
# 2               NaN  ...                  NaN    NaN          NaN         NaN
# 3               NaN  ...                  NaN    NaN          NaN         NaN
# 4               NaN  ...                  NaN    NaN          NaN         NaN
# ...             ...  ...                  ...    ...          ...         ...
# 7603            NaN  ...                  NaN    NaN          NaN         NaN
# 7604            NaN  ...                  NaN    NaN          NaN         NaN
# 7605            NaN  ...                  NaN    NaN          NaN         NaN
# 7606            NaN  ...                  NaN    NaN          NaN         NaN
# 7607            NaN  ...                  NaN    NaN          NaN         NaN
#
#               Recent Trend  Compared to England value or percentiles  \
# 0     Cannot be calculated                              Not compared
# 1     Cannot be calculated                              Not compared
# 2     Cannot be calculated                              Not compared
# 3     Cannot be calculated                              Not compared
# 4     Cannot be calculated                              Not compared
# ...                    ...                                       ...
# 7603  Cannot be calculated                              Not compared
# 7604  Cannot be calculated                              Not compared
# 7605  Cannot be calculated                              Not compared
# 7606  Cannot be calculated                              Not compared
# 7607  Cannot be calculated                              Not compared
#
#       Column not used  Time period Sortable  New data Compared to goal
# 0        Not compared              20190000       NaN              NaN
# 1        Not compared              20190000       NaN              NaN
# 2        Not compared              20190000       NaN              NaN
# 3        Not compared              20190000       NaN              NaN
# 4        Not compared              20190000       NaN              NaN
# ...               ...                   ...       ...              ...
# 7603     Not compared              20190000       NaN              NaN
# 7604     Not compared              20190000       NaN              NaN
# 7605     Not compared              20190000       NaN              NaN
# 7606     Not compared              20190000       NaN              NaN
# 7607     Not compared              20190000       NaN              NaN
#
# [7608 rows x 26 columns]

# %%
gp_and_england_deprivation_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7608 entries, 0 to 7607
# Data columns (total 26 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Indicator ID                              7608 non-null   int64
#  1   Indicator Name                            7608 non-null   object
#  2   Parent Code                               7607 non-null   object
#  3   Parent Name                               7607 non-null   object
#  4   Area Code                                 7608 non-null   object
#  5   Area Name                                 7608 non-null   object
#  6   Area Type                                 7608 non-null   object
#  7   Sex                                       7608 non-null   object
#  8   Age                                       7608 non-null   object
#  9   Category Type                             0 non-null      float64
#  10  Category                                  0 non-null      float64
#  11  Time period                               7608 non-null   int64
#  12  Value                                     7608 non-null   float64
#  13  Lower CI 95.0 limit                       0 non-null      float64
#  14  Upper CI 95.0 limit                       0 non-null      float64
#  15  Lower CI 99.8 limit                       0 non-null      float64
#  16  Upper CI 99.8 limit                       0 non-null      float64
#  17  Count                                     0 non-null      float64
#  18  Denominator                               0 non-null      float64
#  19  Value note                                1 non-null      object
#  20  Recent Trend                              7608 non-null   object
#  21  Compared to England value or percentiles  7608 non-null   object
#  22  Column not used                           7608 non-null   object
#  23  Time period Sortable                      7608 non-null   int64
#  24  New data                                  0 non-null      float64
#  25  Compared to goal                          0 non-null      float64
# dtypes: float64(11), int64(3), object(12)
# memory usage: 1.5+ MB

# %%
gp_and_england_deprivation_score = gp_and_england_deprivation_score[['Area Code', 'Area Name', 'Area Type', 'Time period', 'Value']]
gp_and_england_deprivation_score
# Out:
#       Area Code                   Area Name Area Type  Time period      Value
# 0     E92000001                     England   England         2019  21.722087
# 1        A81001         The Densham Surgery        GP         2019  32.360939
# 2        A81002  Queens Park Medical Centre        GP         2019  31.921958
# 3        A81004     Bluebell Medical Centre        GP         2019  28.024026
# 4        A81005          Springwood Surgery        GP         2019  15.398207
# ...         ...                         ...       ...          ...        ...
# 7603     Y05857                        RHND        GP         2019  23.386000
# 7604     Y06007   Wellbourne Healthcare CIC        GP         2019  44.559787
# 7605     Y06113    QHS GP Care Home Service        GP         2019  32.817919
# 7606     Y06218   Brownsover Medical Centre        GP         2019  15.623656
# 7607     Y06275       Nelson Medical Centre        GP         2019  50.121059
#
# [7608 rows x 5 columns]

# %%
gp_deprivation_score_2019 = gp_and_england_deprivation_score[gp_and_england_deprivation_score['Area Type'].isin(['GP'])]
gp_deprivation_score_2019 = gp_deprivation_score_2019.rename(columns={'Area Code' :'Area_Code', 
                                          'Area Name' : 'GP_Name',
                                          'Area Type' : 'Area_Type',
                                          'Time period' : 'Time_Period', 
                                          'Value' : 'Deprivation_Score_IMD_2019'})
gp_deprivation_score_2019['GP_Name'] = gp_deprivation_score_2019['GP_Name'].str.upper()

# %%
gp_deprivation_score_2019
# Out:
#      Area_Code                          GP_Name Area_Type  Time_Period  \
# 1       A81001              THE DENSHAM SURGERY        GP         2019
# 2       A81002       QUEENS PARK MEDICAL CENTRE        GP         2019
# 3       A81004          BLUEBELL MEDICAL CENTRE        GP         2019
# 4       A81005               SPRINGWOOD SURGERY        GP         2019
# 5       A81006  TENNANT STREET MEDICAL PRACTICE        GP         2019
# ...        ...                              ...       ...          ...
# 7603    Y05857                             RHND        GP         2019
# 7604    Y06007        WELLBOURNE HEALTHCARE CIC        GP         2019
# 7605    Y06113         QHS GP CARE HOME SERVICE        GP         2019
# 7606    Y06218        BROWNSOVER MEDICAL CENTRE        GP         2019
# 7607    Y06275            NELSON MEDICAL CENTRE        GP         2019
#
#       Deprivation_Score_IMD_2019
# 1                      32.360939
# 2                      31.921958
# 3                      28.024026
# 4                      15.398207
# 5                      35.612387
# ...                          ...
# 7603                   23.386000
# 7604                   44.559787
# 7605                   32.817919
# 7606                   15.623656
# 7607                   50.121059
#
# [6980 rows x 5 columns]

# %%
gp_deprivation_score_2019.describe()
# Out:
#        Time_Period  Deprivation_Score_IMD_2019
# count       6980.0                 6980.000000
# mean        2019.0                   23.530374
# std            0.0                   11.666802
# min         2019.0                    3.404973
# 25%         2019.0                   14.089732
# 50%         2019.0                   21.576292
# 75%         2019.0                   30.878554
# max         2019.0                   68.721015

# %%
gp_deprivation_score_2019['GP_Rank'] = gp_deprivation_score_2019['Deprivation_Score_IMD_2019'].rank(ascending = False)
gp_deprivation_score_2019
# Out:
#      Area_Code                          GP_Name Area_Type  Time_Period  \
# 1       A81001              THE DENSHAM SURGERY        GP         2019
# 2       A81002       QUEENS PARK MEDICAL CENTRE        GP         2019
# 3       A81004          BLUEBELL MEDICAL CENTRE        GP         2019
# 4       A81005               SPRINGWOOD SURGERY        GP         2019
# 5       A81006  TENNANT STREET MEDICAL PRACTICE        GP         2019
# ...        ...                              ...       ...          ...
# 7603    Y05857                             RHND        GP         2019
# 7604    Y06007        WELLBOURNE HEALTHCARE CIC        GP         2019
# 7605    Y06113         QHS GP CARE HOME SERVICE        GP         2019
# 7606    Y06218        BROWNSOVER MEDICAL CENTRE        GP         2019
# 7607    Y06275            NELSON MEDICAL CENTRE        GP         2019
#
#       Deprivation_Score_IMD_2019  GP_Rank
# 1                      32.360939   1520.0
# 2                      31.921958   1587.0
# 3                      28.024026   2240.0
# 4                      15.398207   4884.0
# 5                      35.612387   1120.0
# ...                          ...      ...
# 7603                   23.386000   3108.0
# 7604                   44.559787    416.0
# 7605                   32.817919   1450.0
# 7606                   15.623656   4832.0
# 7607                   50.121059    196.0
#
# [6980 rows x 6 columns]

# %%
gp_deprivation_score_2019_ranking = gp_deprivation_score_2019.sort_values(by='GP_Rank', ascending=True)
gp_deprivation_score_2019_ranking['Percentile_Rank'] = gp_deprivation_score_2019.Deprivation_Score_IMD_2019.rank(pct = True)
gp_deprivation_score_2019_ranking
# Out:
#      Area_Code                            GP_Name Area_Type  Time_Period  \
# 6501    N82099           MERE LANE GROUP PRACTICE        GP         2019
# 62      A81621                  THORNTREE SURGERY        GP         2019
# 6530    N82669  GREAT HOMER STREET MEDICAL CENTRE        GP         2019
# 6502    N82101                           KIRKDALE        GP         2019
# 6523    N82651             STANLEY MEDICAL CENTRE        GP         2019
# ...        ...                                ...       ...          ...
# 4968    K82049           HUGHENDEN VALLEY SURGERY        GP         2019
# 4856    K81028             MAGNOLIA HOUSE SURGERY        GP         2019
# 4662    J82099                   RICHMOND SURGERY        GP         2019
# 4899    K81092                 WOOSEHILL PRACTICE        GP         2019
# 4933    K82012                  HIGHFIELD SURGERY        GP         2019
#
#       Deprivation_Score_IMD_2019  GP_Rank  Percentile_Rank
# 6501                   68.721015      1.0         1.000000
# 62                     67.407408      2.0         0.999857
# 6530                   65.248605      3.0         0.999713
# 6502                   65.104433      4.0         0.999570
# 6523                   64.957030      5.0         0.999427
# ...                          ...      ...              ...
# 4968                    4.174575   6976.0         0.000716
# 4856                    4.158261   6977.0         0.000573
# 4662                    4.151031   6978.0         0.000430
# 4899                    3.933291   6979.0         0.000287
# 4933                    3.404973   6980.0         0.000143
#
# [6980 rows x 7 columns]

# %%
gp_deprivation_score_2019_ranking['decile'] = pd.qcut(gp_deprivation_score_2019_ranking['Deprivation_Score_IMD_2019'], 10, labels=['10% least deprived', '20% least deprived', '30% least deprived', '40% least deprived', '50% least deprived', '50% most deprived', '40% most deprived', '30% most deprived', '20% most deprived', '10% most deprived'])
gp_deprivation_score_2019_ranking
# Out:
#      Area_Code                            GP_Name Area_Type  Time_Period  \
# 6501    N82099           MERE LANE GROUP PRACTICE        GP         2019
# 62      A81621                  THORNTREE SURGERY        GP         2019
# 6530    N82669  GREAT HOMER STREET MEDICAL CENTRE        GP         2019
# 6502    N82101                           KIRKDALE        GP         2019
# 6523    N82651             STANLEY MEDICAL CENTRE        GP         2019
# ...        ...                                ...       ...          ...
# 4968    K82049           HUGHENDEN VALLEY SURGERY        GP         2019
# 4856    K81028             MAGNOLIA HOUSE SURGERY        GP         2019
# 4662    J82099                   RICHMOND SURGERY        GP         2019
# 4899    K81092                 WOOSEHILL PRACTICE        GP         2019
# 4933    K82012                  HIGHFIELD SURGERY        GP         2019
#
#       Deprivation_Score_IMD_2019  GP_Rank  Percentile_Rank              decile
# 6501                   68.721015      1.0         1.000000   10% most deprived
# 62                     67.407408      2.0         0.999857   10% most deprived
# 6530                   65.248605      3.0         0.999713   10% most deprived
# 6502                   65.104433      4.0         0.999570   10% most deprived
# 6523                   64.957030      5.0         0.999427   10% most deprived
# ...                          ...      ...              ...                 ...
# 4968                    4.174575   6976.0         0.000716  10% least deprived
# 4856                    4.158261   6977.0         0.000573  10% least deprived
# 4662                    4.151031   6978.0         0.000430  10% least deprived
# 4899                    3.933291   6979.0         0.000287  10% least deprived
# 4933                    3.404973   6980.0         0.000143  10% least deprived
#
# [6980 rows x 8 columns]

# %% [markdown]
# ### Patient Online [December 2019]
# ##### Patient Online is an NHS England programme designed to support GP Practices to offer and promote online services to patients, including access to coded information in records, appointment booking and ordering of repeat prescriptions.
#
# ##### Data are provided by GP system suppliers to NHS Digital on a monthly basis and published on the 15th working day each month pending no issues, otherwise as soon as possible thereafter.
#
# ##### Data: https://digital.nhs.uk/data-and-information/data-collections-and-data-sets/data-collections/pomi

# %% [markdown]
# ### Data dictionary
# ##### Pat_Appts_Use - Total number of appointment scheduling or cancelling transactions using an Online Patient Transaction Service.	Numeric (integer)
#
# ##### Pat_Presc_Use	- Total number of prescriptions ordered using an Online Patient Transaction Service. (Note that ordering several items at once to be counted as one prescription).	Numeric (integer)
#
# ##### Total_Use	- The total number of online transactions that have occurred within the reporting month.	Numeric (integer)

# %%
POMI = pd.read_csv('data/POMI_APR2019_to_MAR2020.csv', sep = ',')
POMI
# Out:
#         report_period_end region_code  \
# 0               30APR2019         Y54
# 1               30APR2019         Y54
# 2               30APR2019         Y54
# 3               30APR2019         Y54
# 4               30APR2019         Y54
# ...                   ...         ...
# 1052124         31MAR2020         Y63
# 1052125         31MAR2020         Y63
# 1052126         31MAR2020         Y63
# 1052127         31MAR2020         Y63
# 1052128         31MAR2020         Y63
#
#                                            region_name subregion_code  \
# 0                                                  NaN            Q74
# 1                                                  NaN            Q74
# 2                                                  NaN            Q74
# 3                                                  NaN            Q74
# 4                                                  NaN            Q74
# ...                                                ...            ...
# 1052124  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052125  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052126  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052127  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052128  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
#
#                                             subregion_name ccg_code  \
# 0               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 1               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 2               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 3               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 4               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# ...                                                    ...      ...
# 1052124  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052125  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052126  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052127  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052128  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
#
#                                         ccg_name practice_code  \
# 0        NHS Hartlepool and Stockton-on-Tees CCG        A81632
# 1        NHS Hartlepool and Stockton-on-Tees CCG        A81632
# 2        NHS Hartlepool and Stockton-on-Tees CCG        A81632
# 3        NHS Hartlepool and Stockton-on-Tees CCG        A81632
# 4        NHS Hartlepool and Stockton-on-Tees CCG        A81632
# ...                                          ...           ...
# 1052124                   NHS North Tyneside CCG        A87612
# 1052125                   NHS North Tyneside CCG        A87612
# 1052126                   NHS North Tyneside CCG        A87612
# 1052127                   NHS North Tyneside CCG        A87612
# 1052128                   NHS North Tyneside CCG        A87612
#
#                      practice_name system_supplier              field   value
# 0           LAWSON STREET PRACTICE             TPP    Pat_Appts_Enbld     0.0
# 1           LAWSON STREET PRACTICE             TPP    Total_Pat_Enbld     0.0
# 2           LAWSON STREET PRACTICE             TPP    Pat_Presc_Enbld     0.0
# 3           LAWSON STREET PRACTICE             TPP          Total_Use     0.0
# 4           LAWSON STREET PRACTICE             TPP      Pat_Appts_Use     0.0
# ...                            ...             ...                ...     ...
# 1052124  WELLSPRING MEDICAL PRACT.             TPP    Sys_Presc_Enbld     2.0
# 1052125  WELLSPRING MEDICAL PRACT.             TPP      Pat_Appts_Use    82.0
# 1052126  WELLSPRING MEDICAL PRACT.             TPP    Pat_Appts_Enbld  2172.0
# 1052127  WELLSPRING MEDICAL PRACT.             TPP    Sys_Appts_Enbld     2.0
# 1052128  WELLSPRING MEDICAL PRACT.             TPP  patient_list_size  5840.0
#
# [1052129 rows x 12 columns]

# %%
POMI['report_period_end'] = pd.to_datetime(POMI['report_period_end'])
POMI['ccg_name'] = POMI['ccg_name'].replace(['NHS Herefordshire CCG'],'NHS Herefordshire and Worcestershire CCG')
POMI['ccg_name'] = POMI['ccg_name'].replace(['NHS Herts Valley CCG'],'NHS Herts Valleys CCG')
POMI['ccg_name'] = POMI['ccg_name'].str.upper()
POMI['practice_name'] = POMI['practice_name'].str.upper()
POMI
# Out:
#         report_period_end region_code  \
# 0              2019-04-30         Y54
# 1              2019-04-30         Y54
# 2              2019-04-30         Y54
# 3              2019-04-30         Y54
# 4              2019-04-30         Y54
# ...                   ...         ...
# 1052124        2020-03-31         Y63
# 1052125        2020-03-31         Y63
# 1052126        2020-03-31         Y63
# 1052127        2020-03-31         Y63
# 1052128        2020-03-31         Y63
#
#                                            region_name subregion_code  \
# 0                                                  NaN            Q74
# 1                                                  NaN            Q74
# 2                                                  NaN            Q74
# 3                                                  NaN            Q74
# 4                                                  NaN            Q74
# ...                                                ...            ...
# 1052124  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052125  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052126  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052127  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
# 1052128  NORTH EAST AND YORKSHIRE COMMISSIONING REGION            Q74
#
#                                             subregion_name ccg_code  \
# 0               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 1               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 2               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 3               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# 4               NHS ENGLAND NORTH (CUMBRIA AND NORTH EAST)      00K
# ...                                                    ...      ...
# 1052124  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052125  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052126  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052127  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
# 1052128  NHS ENGLAND NORTH EAST AND YORKSHIRE (CUMBRIA ...      99C
#
#                                         ccg_name practice_code  \
# 0        NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG        A81632
# 1        NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG        A81632
# 2        NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG        A81632
# 3        NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG        A81632
# 4        NHS HARTLEPOOL AND STOCKTON-ON-TEES CCG        A81632
# ...                                          ...           ...
# 1052124                   NHS NORTH TYNESIDE CCG        A87612
# 1052125                   NHS NORTH TYNESIDE CCG        A87612
# 1052126                   NHS NORTH TYNESIDE CCG        A87612
# 1052127                   NHS NORTH TYNESIDE CCG        A87612
# 1052128                   NHS NORTH TYNESIDE CCG        A87612
#
#                      practice_name system_supplier              field   value
# 0           LAWSON STREET PRACTICE             TPP    Pat_Appts_Enbld     0.0
# 1           LAWSON STREET PRACTICE             TPP    Total_Pat_Enbld     0.0
# 2           LAWSON STREET PRACTICE             TPP    Pat_Presc_Enbld     0.0
# 3           LAWSON STREET PRACTICE             TPP          Total_Use     0.0
# 4           LAWSON STREET PRACTICE             TPP      Pat_Appts_Use     0.0
# ...                            ...             ...                ...     ...
# 1052124  WELLSPRING MEDICAL PRACT.             TPP    Sys_Presc_Enbld     2.0
# 1052125  WELLSPRING MEDICAL PRACT.             TPP      Pat_Appts_Use    82.0
# 1052126  WELLSPRING MEDICAL PRACT.             TPP    Pat_Appts_Enbld  2172.0
# 1052127  WELLSPRING MEDICAL PRACT.             TPP    Sys_Appts_Enbld     2.0
# 1052128  WELLSPRING MEDICAL PRACT.             TPP  patient_list_size  5840.0
#
# [1052129 rows x 12 columns]

# %%
POMI_pivot =  pd.pivot_table(POMI, index = ['report_period_end', 'practice_name', 'practice_code', 'region_code', ], columns = 'field', values = 'value')
POMI_pivot
# Out:
# field                                                                                 New_Pat_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                   10.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                    1.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                   46.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                    2.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                    5.0
# ...                                                                                             ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                   59.0
#                   YOXALL                                   M83013        Y60                   16.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                   18.0
#                   ZAMAN                                    P92005        Y62                   31.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                   98.0
#
# field                                                                                 Pat_Appts_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                    594.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                    380.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                   3703.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                    568.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                    252.0
# ...                                                                                               ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                   1811.0
#                   YOXALL                                   M83013        Y60                   2235.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                    727.0
#                   ZAMAN                                    P92005        Y62                    968.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                   1523.0
#
# field                                                                                 Pat_Appts_Use  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                   12.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                   17.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                  197.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                    1.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                    0.0
# ...                                                                                             ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                   61.0
#                   YOXALL                                   M83013        Y60                   21.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                   26.0
#                   ZAMAN                                    P92005        Y62                   38.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                  254.0
#
# field                                                                                 Pat_DetCodeRec_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                           2.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                          32.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                           1.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                           1.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                           1.0
# ...                                                                                                    ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                          98.0
#                   YOXALL                                   M83013        Y60                        1282.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                          19.0
#                   ZAMAN                                    P92005        Y62                          63.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                         231.0
#
# field                                                                                 Pat_DetCodeRec_Use  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                         NaN
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                         NaN
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                         NaN
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                         NaN
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                         0.0
# ...                                                                                                  ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                       171.0
#                   YOXALL                                   M83013        Y60                       112.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                        40.0
#                   ZAMAN                                    P92005        Y62                        22.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                       366.0
#
# field                                                                                 Pat_Presc_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                    594.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                    380.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                   3703.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                    568.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                    252.0
# ...                                                                                               ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                   1801.0
#                   YOXALL                                   M83013        Y60                   2245.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                    727.0
#                   ZAMAN                                    P92005        Y62                    992.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                   1615.0
#
# field                                                                                 Pat_Presc_Use  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                   92.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                  173.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                  414.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                  182.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                    4.0
# ...                                                                                             ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                  634.0
#                   YOXALL                                   M83013        Y60                  876.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                   73.0
#                   ZAMAN                                    P92005        Y62                  472.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                 1058.0
#
# field                                                                                 Sys_Appts_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                      2.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                      2.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                      2.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                      2.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                      2.0
# ...                                                                                               ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                      2.0
#                   YOXALL                                   M83013        Y60                      2.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                      2.0
#                   ZAMAN                                    P92005        Y62                      2.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                      2.0
#
# field                                                                                 Sys_DetCodeRec_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                           2.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                           2.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                           2.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                           2.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                           2.0
# ...                                                                                                    ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                           2.0
#                   YOXALL                                   M83013        Y60                           2.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                           2.0
#                   ZAMAN                                    P92005        Y62                           2.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                           2.0
#
# field                                                                                 Sys_Presc_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                      2.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                      2.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                      2.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                      2.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                      2.0
# ...                                                                                               ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                      2.0
#                   YOXALL                                   M83013        Y60                      2.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                      2.0
#                   ZAMAN                                    P92005        Y62                      2.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                      2.0
#
# field                                                                                 Total_Pat_Enbld  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                    594.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                    380.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                   3703.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                    568.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                    252.0
# ...                                                                                               ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                   1827.0
#                   YOXALL                                   M83013        Y60                   2255.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                    731.0
#                   ZAMAN                                    P92005        Y62                    993.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                   1617.0
#
# field                                                                                 Total_Use  \
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                NaN
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                NaN
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                NaN
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                NaN
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                4.0
# ...                                                                                         ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62             1138.0
#                   YOXALL                                   M83013        Y60             1177.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56              311.0
#                   ZAMAN                                    P92005        Y62              592.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63             2040.0
#
# field                                                                                 patient_list_size
# report_period_end practice_name                            practice_code region_code
# 2019-04-30        (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI P87657        Y62                     2851.0
#                   1/LOWER BROUGHTON MEDICAL PRACTICE       P87652        Y62                     2146.0
#                   1/MONTON MEDICAL PRACTICE                P87620        Y62                     9382.0
#                   1/SALFORD MEDICAL PRACTICE               P87004        Y62                     3757.0
#                   108 RAWLING ROAD(RAWLING ROAD PRACTICE)  A85609        Y63                     1574.0
# ...                                                                                                 ...
# 2020-03-31        YORKSHIRE STREET MEDICAL CENTRE          P81008        Y62                     6269.0
#                   YOXALL                                   M83013        Y60                     4740.0
#                   ZAIN MEDICAL CENTRE                      E84653        Y56                     2989.0
#                   ZAMAN                                    P92005        Y62                     4178.0
#                   ZETLAND MEDICAL PRACTICE                 A81048        Y63                     7302.0
#
# [80933 rows x 13 columns]

# %%
POMI_filter = POMI_pivot.drop(['New_Pat_Enbld','Pat_Appts_Enbld', 'Pat_DetCodeRec_Enbld','Pat_DetCodeRec_Use','Pat_Presc_Enbld','Sys_Appts_Enbld','Sys_DetCodeRec_Enbld','Sys_Presc_Enbld','Total_Pat_Enbld'], axis=1)
POMI_filter = POMI_filter.reset_index()
POMI_filter
# Out:
# field report_period_end                             practice_name  \
# 0            2019-04-30  (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI
# 1            2019-04-30        1/LOWER BROUGHTON MEDICAL PRACTICE
# 2            2019-04-30                 1/MONTON MEDICAL PRACTICE
# 3            2019-04-30                1/SALFORD MEDICAL PRACTICE
# 4            2019-04-30   108 RAWLING ROAD(RAWLING ROAD PRACTICE)
# ...                 ...                                       ...
# 80928        2020-03-31           YORKSHIRE STREET MEDICAL CENTRE
# 80929        2020-03-31                                    YOXALL
# 80930        2020-03-31                       ZAIN MEDICAL CENTRE
# 80931        2020-03-31                                     ZAMAN
# 80932        2020-03-31                  ZETLAND MEDICAL PRACTICE
#
# field practice_code region_code  Pat_Appts_Use  Pat_Presc_Use  Total_Use  \
# 0            P87657         Y62           12.0           92.0        NaN
# 1            P87652         Y62           17.0          173.0        NaN
# 2            P87620         Y62          197.0          414.0        NaN
# 3            P87004         Y62            1.0          182.0        NaN
# 4            A85609         Y63            0.0            4.0        4.0
# ...             ...         ...            ...            ...        ...
# 80928        P81008         Y62           61.0          634.0     1138.0
# 80929        M83013         Y60           21.0          876.0     1177.0
# 80930        E84653         Y56           26.0           73.0      311.0
# 80931        P92005         Y62           38.0          472.0      592.0
# 80932        A81048         Y63          254.0         1058.0     2040.0
#
# field  patient_list_size
# 0                 2851.0
# 1                 2146.0
# 2                 9382.0
# 3                 3757.0
# 4                 1574.0
# ...                  ...
# 80928             6269.0
# 80929             4740.0
# 80930             2989.0
# 80931             4178.0
# 80932             7302.0
#
# [80933 rows x 8 columns]

# %%
patient_list_size_check = POMI_filter[['report_period_end','patient_list_size']].groupby('report_period_end').sum()
patient_list_size_check
# Out:
# field              patient_list_size
# report_period_end
# 2019-04-30                59036151.0
# 2019-05-31                59097924.0
# 2019-06-30                59256719.0
# 2019-07-31                59322296.0
# 2019-08-31                59428950.0
# 2019-09-30                59490839.0
# 2019-10-31                59649310.0
# 2019-11-30                59756044.0
# 2019-12-31                59854026.0
# 2020-01-31                59868674.0
# 2020-02-29                59971452.0
# 2020-03-31                60027199.0

# %%
POMI_filter['report_period_end'] = pd.to_datetime(POMI_filter['report_period_end'])
POMI_filter
# Out:
# field report_period_end                             practice_name  \
# 0            2019-04-30  (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI
# 1            2019-04-30        1/LOWER BROUGHTON MEDICAL PRACTICE
# 2            2019-04-30                 1/MONTON MEDICAL PRACTICE
# 3            2019-04-30                1/SALFORD MEDICAL PRACTICE
# 4            2019-04-30   108 RAWLING ROAD(RAWLING ROAD PRACTICE)
# ...                 ...                                       ...
# 80928        2020-03-31           YORKSHIRE STREET MEDICAL CENTRE
# 80929        2020-03-31                                    YOXALL
# 80930        2020-03-31                       ZAIN MEDICAL CENTRE
# 80931        2020-03-31                                     ZAMAN
# 80932        2020-03-31                  ZETLAND MEDICAL PRACTICE
#
# field practice_code region_code  Pat_Appts_Use  Pat_Presc_Use  Total_Use  \
# 0            P87657         Y62           12.0           92.0        NaN
# 1            P87652         Y62           17.0          173.0        NaN
# 2            P87620         Y62          197.0          414.0        NaN
# 3            P87004         Y62            1.0          182.0        NaN
# 4            A85609         Y63            0.0            4.0        4.0
# ...             ...         ...            ...            ...        ...
# 80928        P81008         Y62           61.0          634.0     1138.0
# 80929        M83013         Y60           21.0          876.0     1177.0
# 80930        E84653         Y56           26.0           73.0      311.0
# 80931        P92005         Y62           38.0          472.0      592.0
# 80932        A81048         Y63          254.0         1058.0     2040.0
#
# field  patient_list_size
# 0                 2851.0
# 1                 2146.0
# 2                 9382.0
# 3                 3757.0
# 4                 1574.0
# ...                  ...
# 80928             6269.0
# 80929             4740.0
# 80930             2989.0
# 80931             4178.0
# 80932             7302.0
#
# [80933 rows x 8 columns]

# %%
POMI_filter.dtypes
# Out:
# field
# report_period_end    datetime64[ns]
# practice_name                object
# practice_code                object
# region_code                  object
# Pat_Appts_Use               float64
# Pat_Presc_Use               float64
# Total_Use                   float64
# patient_list_size           float64
# dtype: object

# %%
POMI_dec_2019 = POMI_filter[POMI_filter['report_period_end'] == '2019-12-31']
POMI_dec_2019
# Out:
# field report_period_end                             practice_name  \
# 54139        2019-12-31  (IRLAM) SALFORD CARE CTRS MEDICAL PRACTI
# 54140        2019-12-31                 1/MONTON MEDICAL PRACTICE
# 54141        2019-12-31                1/SALFORD MEDICAL PRACTICE
# 54142        2019-12-31   108 RAWLING ROAD(RAWLING ROAD PRACTICE)
# 54143        2019-12-31                            15 SEFTON ROAD
# ...                 ...                                       ...
# 60848        2019-12-31           YORKSHIRE STREET MEDICAL CENTRE
# 60849        2019-12-31                                    YOXALL
# 60850        2019-12-31                       ZAIN MEDICAL CENTRE
# 60851        2019-12-31                                     ZAMAN
# 60852        2019-12-31                  ZETLAND MEDICAL PRACTICE
#
# field practice_code region_code  Pat_Appts_Use  Pat_Presc_Use  Total_Use  \
# 54139        P87657         Y62           10.0          101.0        NaN
# 54140        P87620         Y62           93.0          419.0        NaN
# 54141        P87004         Y62            0.0          174.0        NaN
# 54142        A85609         Y63            0.0            6.0        6.0
# 54143        N84035         Y62           14.0          254.0      455.0
# ...             ...         ...            ...            ...        ...
# 60848        P81008         Y62          129.0          521.0     1028.0
# 60849        M83013         Y60           72.0          662.0      984.0
# 60850        E84653         Y56           55.0           61.0      329.0
# 60851        P92005         Y62           95.0          338.0      441.0
# 60852        A81048         Y63          404.0          654.0     1216.0
#
# field  patient_list_size
# 54139             2822.0
# 54140             9466.0
# 54141             3701.0
# 54142             1442.0
# 54143             4370.0
# ...                  ...
# 60848             6231.0
# 60849             4767.0
# 60850             2957.0
# 60851             4180.0
# 60852             7299.0
#
# [6714 rows x 8 columns]

# %%
POMI_dec_2019_gp = POMI_dec_2019 [['practice_name', 'practice_code', 'Pat_Appts_Use', 'Pat_Presc_Use', 'Total_Use', 'patient_list_size']].groupby(['practice_code', 'practice_name']).sum()
POMI_dec_2019_gp = POMI_dec_2019_gp.reset_index()

# %%
POMI_dec_2019_gp
# Out:
# field practice_code                    practice_name  Pat_Appts_Use  \
# 0            A81001              THE DENSHAM SURGERY           31.0
# 1            A81002       QUEENS PARK MEDICAL CENTRE          625.0
# 2            A81004          BLUEBELL MEDICAL CENTRE          226.0
# 3            A81005               SPRINGWOOD SURGERY          211.0
# 4            A81006  TENNANT STREET MEDICAL PRACTICE          418.0
# ...             ...                              ...            ...
# 6709         Y06356        BILBOROUGH MEDICAL CENTRE          235.0
# 6710         Y06378       HEATH STREET HEALTH CENTRE            9.0
# 6711         Y06443         WHYBURN MEDICAL PRACTICE          408.0
# 6712         Y06487    BABYLON GP AT HAND BIRMINGHAM            0.0
# 6713         Y06507               PEACOCK HEALTHCARE          290.0
#
# field  Pat_Presc_Use  Total_Use  patient_list_size
# 0              751.0      994.0             4097.0
# 1             3294.0     4774.0            19304.0
# 2             1255.0     1701.0            10940.0
# 3              682.0     1254.0             8099.0
# 4             2809.0     3396.0            14779.0
# ...              ...        ...                ...
# 6709           255.0      583.0             9752.0
# 6710             9.0       48.0             6222.0
# 6711          1363.0     1868.0            11669.0
# 6712             0.0        0.0                2.0
# 6713           257.0      581.0             5559.0
#
# [6714 rows x 6 columns]

# %%
patient_list_size_check_gp = POMI_dec_2019_gp['patient_list_size'].sum()
patient_list_size_check_gp
# Out:
# 59854026.0

# %% [markdown]
# ### Use of Patient Online Per 1000 Patients (Per Capita)

# %%
GP_POMI_IMD_2019 = gp_deprivation_score_2019_ranking.merge(POMI_dec_2019_gp_per_1000, how='inner', left_on='Area_Code', right_on ='practice_code')
GP_POMI_IMD_2019
# Out:
#      Area_Code                            GP_Name Area_Type  Time_Period  \
# 0       N82099           MERE LANE GROUP PRACTICE        GP         2019
# 1       A81621                  THORNTREE SURGERY        GP         2019
# 2       N82669  GREAT HOMER STREET MEDICAL CENTRE        GP         2019
# 3       N82101                           KIRKDALE        GP         2019
# 4       N82651             STANLEY MEDICAL CENTRE        GP         2019
# ...        ...                                ...       ...          ...
# 6703    K82049           HUGHENDEN VALLEY SURGERY        GP         2019
# 6704    K81028             MAGNOLIA HOUSE SURGERY        GP         2019
# 6705    J82099                   RICHMOND SURGERY        GP         2019
# 6706    K81092                 WOOSEHILL PRACTICE        GP         2019
# 6707    K82012                  HIGHFIELD SURGERY        GP         2019
#
#       Deprivation_Score_IMD_2019  GP_Rank  Percentile_Rank  \
# 0                      68.721015      1.0         1.000000
# 1                      67.407408      2.0         0.999857
# 2                      65.248605      3.0         0.999713
# 3                      65.104433      4.0         0.999570
# 4                      64.957030      5.0         0.999427
# ...                          ...      ...              ...
# 6703                    4.174575   6976.0         0.000716
# 6704                    4.158261   6977.0         0.000573
# 6705                    4.151031   6978.0         0.000430
# 6706                    3.933291   6979.0         0.000287
# 6707                    3.404973   6980.0         0.000143
#
#                   decile practice_code                      practice_name  \
# 0      10% most deprived        N82099           MERE LANE GROUP PRACTICE
# 1      10% most deprived        A81621                  THORNTREE SURGERY
# 2      10% most deprived        N82669  GREAT HOMER STREET MEDICAL CENTRE
# 3      10% most deprived        N82101            KIRKDALE MEDICAL CENTRE
# 4      10% most deprived        N82651             STANLEY MEDICAL CENTRE
# ...                  ...           ...                                ...
# 6703  10% least deprived        K82049           HUGHENDEN VALLEY SURGERY
# 6704  10% least deprived        K81028             MAGNOLIA HOUSE SURGERY
# 6705  10% least deprived        J82099                   RICHMOND SURGERY
# 6706  10% least deprived        K81092                 WOOSEHILL PRACTICE
# 6707  10% least deprived        K82012                  HIGHFIELD SURGERY
#
#       Pat_Appts_Use  Pat_Presc_Use  Total_Use  patient_list_size  \
# 0              28.0          392.0      681.0             7942.0
# 1              36.0           57.0      124.0             2358.0
# 2              79.0          263.0      544.0             3277.0
# 3              12.0          135.0      232.0             2714.0
# 4              11.0          115.0      223.0             4544.0
# ...             ...            ...        ...                ...
# 6703          194.0         1777.0     2213.0            12631.0
# 6704          109.0          337.0      673.0             8980.0
# 6705          235.0          738.0     1264.0            14130.0
# 6706          161.0          801.0     1172.0            13601.0
# 6707          123.0          700.0     1065.0             6827.0
#
#       Pat_Presc_Use_per_1000  Pat_Appts_Use_per_1000
# 0                      49.36                    3.53
# 1                      24.17                   15.27
# 2                      80.26                   24.11
# 3                      49.74                    4.42
# 4                      25.31                    2.42
# ...                      ...                     ...
# 6703                  140.69                   15.36
# 6704                   37.53                   12.14
# 6705                   52.23                   16.63
# 6706                   58.89                   11.84
# 6707                  102.53                   18.02
#
# [6708 rows x 16 columns]

# %%
POMI_dec_2019_gp['Pat_Presc_Use_per_1000'] = (POMI_dec_2019_gp['Pat_Presc_Use'] / POMI_dec_2019_gp['patient_list_size']) * 1000
POMI_dec_2019_gp['Pat_Appts_Use_per_1000'] = (POMI_dec_2019_gp['Pat_Appts_Use'] / POMI_dec_2019_gp['patient_list_size']) * 1000
POMI_dec_2019_gp_per_1000 = POMI_dec_2019_gp.round(2)
POMI_dec_2019_gp_per_1000
# Out:
# field practice_code                    practice_name  Pat_Appts_Use  \
# 0            A81001              THE DENSHAM SURGERY           31.0
# 1            A81002       QUEENS PARK MEDICAL CENTRE          625.0
# 2            A81004          BLUEBELL MEDICAL CENTRE          226.0
# 3            A81005               SPRINGWOOD SURGERY          211.0
# 4            A81006  TENNANT STREET MEDICAL PRACTICE          418.0
# ...             ...                              ...            ...
# 6709         Y06356        BILBOROUGH MEDICAL CENTRE          235.0
# 6710         Y06378       HEATH STREET HEALTH CENTRE            9.0
# 6711         Y06443         WHYBURN MEDICAL PRACTICE          408.0
# 6712         Y06487    BABYLON GP AT HAND BIRMINGHAM            0.0
# 6713         Y06507               PEACOCK HEALTHCARE          290.0
#
# field  Pat_Presc_Use  Total_Use  patient_list_size  Pat_Presc_Use_per_1000  \
# 0              751.0      994.0             4097.0                  183.30
# 1             3294.0     4774.0            19304.0                  170.64
# 2             1255.0     1701.0            10940.0                  114.72
# 3              682.0     1254.0             8099.0                   84.21
# 4             2809.0     3396.0            14779.0                  190.07
# ...              ...        ...                ...                     ...
# 6709           255.0      583.0             9752.0                   26.15
# 6710             9.0       48.0             6222.0                    1.45
# 6711          1363.0     1868.0            11669.0                  116.81
# 6712             0.0        0.0                2.0                    0.00
# 6713           257.0      581.0             5559.0                   46.23
#
# field  Pat_Appts_Use_per_1000
# 0                        7.57
# 1                       32.38
# 2                       20.66
# 3                       26.05
# 4                       28.28
# ...                       ...
# 6709                    24.10
# 6710                     1.45
# 6711                    34.96
# 6712                     0.00
# 6713                    52.17
#
# [6714 rows x 8 columns]

# %% [markdown]
# ### Joining English Indices of Deprivation 2019 dataframe with Patient Online dataframe

# %%
GP_POMI_IMD_2019 = gp_deprivation_score_2019_ranking.merge(POMI_dec_2019_gp_per_1000, left_on='Area_Code', right_on ='practice_code')
GP_POMI_IMD_2019
# Out:
#      Area_Code                            GP_Name Area_Type  Time_Period  \
# 0       N82099           MERE LANE GROUP PRACTICE        GP         2019
# 1       A81621                  THORNTREE SURGERY        GP         2019
# 2       N82669  GREAT HOMER STREET MEDICAL CENTRE        GP         2019
# 3       N82101                           KIRKDALE        GP         2019
# 4       N82651             STANLEY MEDICAL CENTRE        GP         2019
# ...        ...                                ...       ...          ...
# 6703    K82049           HUGHENDEN VALLEY SURGERY        GP         2019
# 6704    K81028             MAGNOLIA HOUSE SURGERY        GP         2019
# 6705    J82099                   RICHMOND SURGERY        GP         2019
# 6706    K81092                 WOOSEHILL PRACTICE        GP         2019
# 6707    K82012                  HIGHFIELD SURGERY        GP         2019
#
#       Deprivation_Score_IMD_2019  GP_Rank  Percentile_Rank  \
# 0                      68.721015      1.0         1.000000
# 1                      67.407408      2.0         0.999857
# 2                      65.248605      3.0         0.999713
# 3                      65.104433      4.0         0.999570
# 4                      64.957030      5.0         0.999427
# ...                          ...      ...              ...
# 6703                    4.174575   6976.0         0.000716
# 6704                    4.158261   6977.0         0.000573
# 6705                    4.151031   6978.0         0.000430
# 6706                    3.933291   6979.0         0.000287
# 6707                    3.404973   6980.0         0.000143
#
#                   decile practice_code                      practice_name  \
# 0      10% most deprived        N82099           MERE LANE GROUP PRACTICE
# 1      10% most deprived        A81621                  THORNTREE SURGERY
# 2      10% most deprived        N82669  GREAT HOMER STREET MEDICAL CENTRE
# 3      10% most deprived        N82101            KIRKDALE MEDICAL CENTRE
# 4      10% most deprived        N82651             STANLEY MEDICAL CENTRE
# ...                  ...           ...                                ...
# 6703  10% least deprived        K82049           HUGHENDEN VALLEY SURGERY
# 6704  10% least deprived        K81028             MAGNOLIA HOUSE SURGERY
# 6705  10% least deprived        J82099                   RICHMOND SURGERY
# 6706  10% least deprived        K81092                 WOOSEHILL PRACTICE
# 6707  10% least deprived        K82012                  HIGHFIELD SURGERY
#
#       Pat_Appts_Use  Pat_Presc_Use  Total_Use  patient_list_size  \
# 0              28.0          392.0      681.0             7942.0
# 1              36.0           57.0      124.0             2358.0
# 2              79.0          263.0      544.0             3277.0
# 3              12.0          135.0      232.0             2714.0
# 4              11.0          115.0      223.0             4544.0
# ...             ...            ...        ...                ...
# 6703          194.0         1777.0     2213.0            12631.0
# 6704          109.0          337.0      673.0             8980.0
# 6705          235.0          738.0     1264.0            14130.0
# 6706          161.0          801.0     1172.0            13601.0
# 6707          123.0          700.0     1065.0             6827.0
#
#       Pat_Presc_Use_per_1000  Pat_Appts_Use_per_1000
# 0                      49.36                    3.53
# 1                      24.17                   15.27
# 2                      80.26                   24.11
# 3                      49.74                    4.42
# 4                      25.31                    2.42
# ...                      ...                     ...
# 6703                  140.69                   15.36
# 6704                   37.53                   12.14
# 6705                   52.23                   16.63
# 6706                   58.89                   11.84
# 6707                  102.53                   18.02
#
# [6708 rows x 16 columns]

# %%
GP_POMI_IMD_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6708 entries, 0 to 6707
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Area_Code                   6708 non-null   object
#  1   GP_Name                     6708 non-null   object
#  2   Area_Type                   6708 non-null   object
#  3   Time_Period                 6708 non-null   int64
#  4   Deprivation_Score_IMD_2019  6708 non-null   float64
#  5   GP_Rank                     6708 non-null   float64
#  6   Percentile_Rank             6708 non-null   float64
#  7   decile                      6708 non-null   category
#  8   practice_code               6708 non-null   object
#  9   practice_name               6708 non-null   object
#  10  Pat_Appts_Use               6708 non-null   float64
#  11  Pat_Presc_Use               6708 non-null   float64
#  12  Total_Use                   6708 non-null   float64
#  13  patient_list_size           6708 non-null   float64
#  14  Pat_Presc_Use_per_1000      6708 non-null   float64
#  15  Pat_Appts_Use_per_1000      6708 non-null   float64
# dtypes: category(1), float64(9), int64(1), object(5)
# memory usage: 845.4+ KB

# %% [markdown]
# #### These GP practices are missing from Fingertips / The English Indices of Deprivation 2019 Dataframe so are exlucded from our analysis

# %%
missing_gps = pd.merge(POMI_dec_2019_gp_per_1000, 
                    GP_POMI_IMD_2019,
                     how = 'outer',
                     left_on = 'practice_code',
                     right_on = 'Area_Code', 
                     indicator = True)

deleted_rows = missing_gps.loc[missing_gps._merge == "left_only",]
deleted_rows
# Out:
#      practice_code_x                practice_name_x  Pat_Appts_Use_x  \
# 6708          Y06345         BROMLEAG CARE PRACTICE              0.0
# 6709          Y06356      BILBOROUGH MEDICAL CENTRE            235.0
# 6710          Y06378     HEATH STREET HEALTH CENTRE              9.0
# 6711          Y06443       WHYBURN MEDICAL PRACTICE            408.0
# 6712          Y06487  BABYLON GP AT HAND BIRMINGHAM              0.0
# 6713          Y06507             PEACOCK HEALTHCARE            290.0
#
#       Pat_Presc_Use_x  Total_Use_x  patient_list_size_x  \
# 6708            429.0        455.0               1229.0
# 6709            255.0        583.0               9752.0
# 6710              9.0         48.0               6222.0
# 6711           1363.0       1868.0              11669.0
# 6712              0.0          0.0                  2.0
# 6713            257.0        581.0               5559.0
#
#       Pat_Presc_Use_per_1000_x  Pat_Appts_Use_per_1000_x Area_Code GP_Name  \
# 6708                    349.06                      0.00       NaN     NaN
# 6709                     26.15                     24.10       NaN     NaN
# 6710                      1.45                      1.45       NaN     NaN
# 6711                    116.81                     34.96       NaN     NaN
# 6712                      0.00                      0.00       NaN     NaN
# 6713                     46.23                     52.17       NaN     NaN
#
#       ... decile  practice_code_y  practice_name_y  Pat_Appts_Use_y  \
# 6708  ...    NaN              NaN              NaN              NaN
# 6709  ...    NaN              NaN              NaN              NaN
# 6710  ...    NaN              NaN              NaN              NaN
# 6711  ...    NaN              NaN              NaN              NaN
# 6712  ...    NaN              NaN              NaN              NaN
# 6713  ...    NaN              NaN              NaN              NaN
#
#       Pat_Presc_Use_y Total_Use_y patient_list_size_y  \
# 6708              NaN         NaN                 NaN
# 6709              NaN         NaN                 NaN
# 6710              NaN         NaN                 NaN
# 6711              NaN         NaN                 NaN
# 6712              NaN         NaN                 NaN
# 6713              NaN         NaN                 NaN
#
#      Pat_Presc_Use_per_1000_y  Pat_Appts_Use_per_1000_y     _merge
# 6708                      NaN                       NaN  left_only
# 6709                      NaN                       NaN  left_only
# 6710                      NaN                       NaN  left_only
# 6711                      NaN                       NaN  left_only
# 6712                      NaN                       NaN  left_only
# 6713                      NaN                       NaN  left_only
#
# [6 rows x 25 columns]

# %% [markdown]
# #### Deprivation_Score_IMD_2019 vs Pat_Presc_Use_per_1000

# %%
GP_POMI_IMD_2019.plot(x='Deprivation_Score_IMD_2019', y='Pat_Presc_Use_per_1000', style='o')  
plt.title('Deprivation_Score_IMD_2019 vs Pat_Presc_Use_per_1000')  
plt.xlabel('Deprivation_Score_IMD_2019')  
plt.ylabel('Pat_Presc_Use_per_1000')  
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.tight_layout()
seabornInstance.displot(GP_POMI_IMD_2019['Deprivation_Score_IMD_2019'])

# %%
X = GP_POMI_IMD_2019['Deprivation_Score_IMD_2019'].values.reshape(-1,1)
y = GP_POMI_IMD_2019['Pat_Presc_Use_per_1000'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [81.25930242]
# [[-0.9455248]]

# %%
y_pred = regressor.predict(X_test)

# %%
actual_vs_predicted = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
actual_vs_predicted
# Out:
#       Actual  Predicted
# 0      18.59  31.877577
# 1      32.27  71.344655
# 2      15.33  41.305042
# 3      38.63  54.323933
# 4      46.34  30.828542
# ...      ...        ...
# 1337   46.24  60.528282
# 1338   89.59  60.810755
# 1339   76.38  67.780651
# 1340   25.84  65.836501
# 1341   54.74  58.465814
#
# [1342 rows x 2 columns]

# %%
actual_vs_predicted_viz= actual_vs_predicted.head(25)
actual_vs_predicted_viz.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 32.48960328343977
# Mean Squared Error: 1691.2358724137778
# Root Mean Squared Error: 41.124638264838

# %% [markdown]
# #### Deprivation_Score_IMD_2019 vs Pat_Appt_Use_per_1000

# %%
GP_POMI_IMD_2019.plot(x='Deprivation_Score_IMD_2019', y='Pat_Appts_Use_per_1000', style='o')  
plt.title('Deprivation_Score_IMD_2019 vs Pat_Appts_Use_per_1000')  
plt.xlabel('Deprivation_Score_IMD_2019')  
plt.ylabel('Pat_Appts_Use_per_1000')  
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.tight_layout()
seabornInstance.displot(GP_POMI_IMD_2019['Deprivation_Score_IMD_2019'])

# %%
X = GP_POMI_IMD_2019['Deprivation_Score_IMD_2019'].values.reshape(-1,1)
y = GP_POMI_IMD_2019['Pat_Appts_Use_per_1000'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [23.78469414]
# [[-0.21981555]]

# %%
y_pred = regressor.predict(X_test)

# %%
actual_vs_predicted = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
actual_vs_predicted
# Out:
#       Actual  Predicted
# 0       0.16  12.304433
# 1      24.08  21.479737
# 2      13.70  14.496130
# 3       5.87  17.522761
# 4       6.89  12.060554
# ...      ...        ...
# 1337   24.08  18.965148
# 1338    9.72  19.030817
# 1339   13.89  20.651178
# 1340    8.61  20.199202
# 1341   18.89  18.485665
#
# [1342 rows x 2 columns]

# %%
actual_vs_predicted_viz= actual_vs_predicted.head(25)
actual_vs_predicted_viz.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 13.331859331614135
# Mean Squared Error: 444.81488927040436
# Root Mean Squared Error: 21.090635108275055
